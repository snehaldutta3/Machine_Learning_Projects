# %% [markdown]
# # **Importing the Depenencies**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # **Loading the dataset to a pandas dataframe**

# %%
credit_card_data = pd.read_csv('/content/credit_data.csv')

# %%
# first five rows
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# last five rows
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 55546  47004  1.283418  0.354874  0.158519  0.607335 -0.186818 -0.865444
# 55547  47005 -0.969584 -0.514812  1.010076 -0.492493 -1.074442  0.812377
# 55548  47005 -0.448083  0.936043  1.308078  0.424255  0.141240 -0.224215
# 55549  47005  0.616391 -0.770376 -0.306186  1.374006 -0.177289  0.186992
# 55550  47005 -2.212795  0.701029  1.063799  1.449808 -1.045775  0.416184
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 55546  0.084609 -0.186195  0.042276  ... -0.310652 -0.887568  0.084508
# 55547  1.739011  0.069684 -0.741379  ...  0.137958 -0.378729  0.989131
# 55548  1.114183 -0.286478 -0.144553  ...  0.084264  0.345878 -0.222427
# 55549  0.417697  0.073573 -0.009001  ...  0.182098 -0.039148 -0.409170
# 55550 -1.071689 -2.157124  0.014993  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55551 entries, 0 to 55550
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    55551 non-null  int64
#  1   V1      55551 non-null  float64
#  2   V2      55551 non-null  float64
#  3   V3      55551 non-null  float64
#  4   V4      55551 non-null  float64
#  5   V5      55551 non-null  float64
#  6   V6      55551 non-null  float64
#  7   V7      55551 non-null  float64
#  8   V8      55551 non-null  float64
#  9   V9      55551 non-null  float64
#  10  V10     55551 non-null  float64
#  11  V11     55551 non-null  float64
#  12  V12     55551 non-null  float64
#  13  V13     55551 non-null  float64
#  14  V14     55551 non-null  float64
#  15  V15     55550 non-null  float64
#  16  V16     55550 non-null  float64
#  17  V17     55550 non-null  float64
#  18  V18     55550 non-null  float64
#  19  V19     55550 non-null  float64
# ...

# %%
# checking if there is missing value (column)
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# dropping the missing values
credit_card_data.dropna(inplace=True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# dsitribution of legit transaction and fraudulent transaction
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    55394
# 1.0      156
# Name: count, dtype: int64

# %% [markdown]
# IN the above case data is much unbalanced its difficult to predict by the model

# %%
# separating the data for anyalsis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print (legit.shape)
print (fraud.shape)
# Out:
# (55394, 31)
# (156, 31)

# %%
# satistical measure of the data
legit.Amount.describe()
# Out:
# count    55394.000000
# mean        94.703197
# std        257.030241
# min          0.000000
# 25%          7.680000
# 50%         25.790000
# 75%         86.907500
# max      12910.930000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     156.000000
# mean       95.758013
# std       228.178528
# min         0.000000
# 25%         1.000000
# 50%         4.930000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both transaction
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    30600.766816 -0.222674 -0.018472  0.721307  0.161099 -0.244542
# 1.0    27835.794872 -7.345427  5.255872 -9.922599  5.709553 -5.426307
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.107561 -0.096454  0.045242  0.092669  ...  0.046438 -0.031322
# 1.0   -2.204159 -7.736462  3.560034 -3.453697  ...  0.449731  0.881689
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.106872 -0.038113  0.007273  0.134525  0.020398  0.002097  0.004102
# 1.0   -0.211806 -0.275513 -0.088146  0.239724  0.127377  0.580843  0.031086
#
#           Amount
# Class
# 0.0    94.703197
# 1.0    95.758013
#
# [2 rows x 30 columns]

# %% [markdown]
# # **Under-Sampling
# dataset containing similar distribution of normal and fraud transaction **

# %%
legit_sample = legit.sample(n=156)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 54081  46278 -0.499403  0.030379  2.310068  0.691552 -0.529505  1.343338
# 48885  43823  1.254378  0.202912  0.262618  0.713932 -0.557998 -1.122879
# 30338  35876  1.152048 -0.110230 -0.989772  0.099797  2.021742  3.484893
# 19016  29959  0.988983 -0.601270  1.173438  0.335558 -1.186225 -0.055901
# 32817  36976  0.626500 -2.264869 -0.142670 -1.690312 -1.830812 -0.764239
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 54081 -0.393565  0.549938  1.023814  ...  0.042562  0.439844 -0.331090
# 48885 -0.054321 -0.085542  0.347926  ... -0.311430 -1.000619  0.154212
# 30338 -0.457753  0.848919 -0.095229  ... -0.296702 -1.162356  0.059153
# 19016 -0.566627  0.110102  1.061081  ... -0.127385 -0.222299  0.070084
# 32817 -0.231582 -0.235358  0.696352  ... -0.169052 -0.749283 -0.395147
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 52521  45501  1.001992  0.047938 -0.349002  1.493958  0.186939  0.190966
# 52584  45541 -1.519244  2.308492 -1.503599  2.064101 -1.000845 -1.016897
# 53591  46057 -1.309441  1.786495 -1.371070  1.214335 -0.336642 -1.390120
# 53794  46149 -1.346509  2.132431 -1.854355  2.116998 -1.070378 -1.092671
# 55401  46925 -0.481531  1.059542  0.647117  0.905586  0.819368 -0.091184
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 52521 -0.001112  0.147140  0.580415  ... -0.334417 -1.014315 -0.128427
# 52584 -2.059731 -0.275166 -1.562206  ...  1.307871  0.102826 -0.017746
# 53591 -1.709109  0.667748 -1.699809  ...  0.533521 -0.022180 -0.299556
# 53794 -2.230986  1.036425 -1.895516  ...  0.609508  0.202874 -0.060791
# 55401  0.504135  0.161064 -0.765054  ...  0.070633  0.192491 -0.174659
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    156
# 1.0    156
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    29926.410256 -0.218330  0.177630  0.647160  0.243787 -0.130365
# 1.0    27835.794872 -7.345427  5.255872 -9.922599  5.709553 -5.426307
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.117637 -0.081819  0.133714  0.142692  ...  0.013855 -0.064298
# 1.0   -2.204159 -7.736462  3.560034 -3.453697  ...  0.449731  0.881689
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.183707 -0.067236  0.067407  0.164075  0.003682  0.003872  0.021720
# 1.0   -0.211806 -0.275513 -0.088146  0.239724  0.127377  0.580843  0.031086
#
#           Amount
# Class
# 0.0    74.435577
# 1.0    95.758013
#
# [2 rows x 30 columns]

# %% [markdown]
# # **Splitting the data into features and target **

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 54081  46278 -0.499403  0.030379  2.310068  0.691552 -0.529505  1.343338
# 48885  43823  1.254378  0.202912  0.262618  0.713932 -0.557998 -1.122879
# 30338  35876  1.152048 -0.110230 -0.989772  0.099797  2.021742  3.484893
# 19016  29959  0.988983 -0.601270  1.173438  0.335558 -1.186225 -0.055901
# 32817  36976  0.626500 -2.264869 -0.142670 -1.690312 -1.830812 -0.764239
# ...      ...       ...       ...       ...       ...       ...       ...
# 52521  45501  1.001992  0.047938 -0.349002  1.493958  0.186939  0.190966
# 52584  45541 -1.519244  2.308492 -1.503599  2.064101 -1.000845 -1.016897
# 53591  46057 -1.309441  1.786495 -1.371070  1.214335 -0.336642 -1.390120
# 53794  46149 -1.346509  2.132431 -1.854355  2.116998 -1.070378 -1.092671
# 55401  46925 -0.481531  1.059542  0.647117  0.905586  0.819368 -0.091184
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 54081    0.0
# 48885    0.0
# 30338    0.0
# 19016    0.0
# 32817    0.0
#         ...
# 52521    1.0
# 52584    1.0
# 53591    1.0
# 53794    1.0
# 55401    1.0
# Name: Class, Length: 312, dtype: float64

# %% [markdown]
# # Spilt the data into Training data & Testing data

# %%
X_train , X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (312, 30) (249, 30) (63, 30)

# %% [markdown]
# # **Model TRaining **

# %%
model = LogisticRegression()

# %%
# training the LOgistic Regression Model with Training data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # Model evaluation

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9759036144578314

# %% [markdown]
# # Accuracy on test data

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.9365079365079365
